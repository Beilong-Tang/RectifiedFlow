# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
npy_path = "/home/btang5/work/2025/RectifiedFlow/ImageGeneration/logs/1_rectified_flow/eval/ckpt_8/samples_rank_3_1.npz"

res = np.load(npy_path)
print(res['samples'].shape)
# Out:
# (128, 32, 32, 3)

# %%
plt.imshow(res['samples'][23])
